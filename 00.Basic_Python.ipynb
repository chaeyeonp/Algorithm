# %% [markdown]
# ## 함수
#
# ![0-22.00120S10908ONE%2099E1471681862%20944C.png](attachment:0-22.00120S10908ONE%2099E1471681862%20944C.png)
#
# 1. 여러개의 반환값 가질 수 있음

# %%
def operator(a,b):
    return a+b,a-b, a*b, a/b


a,b,c,d = operator(3,7)

print(a,b,c,d)
# Out:
# 10 -4 21 0.42857142857142855
